# %% [markdown]
# **Board game analysis**
#
# As a big fan of board games, and a junior data analyst, I decided to combine my two passions and to analyze a board games dataset. The dataset was downloaded from https://www.kaggle.com/datasets/mshepherd/board-games?select=bga_GameItem.csv. Briefly, these data are scraped from  BoardGameGeek website, contains ~119000 rows (board games). Let's explore!

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('bgg_GameItem.csv', index_col='bgg_id')
df.head(5)
# Out:
#                   name    year game_type designer       artist  \
# bgg_id
# 1           Die Macher  1986.0      5497        1   12517,4959
# 2         Dragonmaster  1981.0      5497     8384        12424
# 3              Samurai  1998.0      5497        2        11883
# 4       Tal der Könige  1992.0      5497     8008         2277
# 5              Acquire  1964.0      5497        4  12658,18317
#
#                                                 publisher  min_players  \
# bgg_id
# 1            133,2,24883,2726,15108,39249,11652,5382,8147          3.0
# 2                                                   64,20          3.0
# 3       17,133,267,29,7340,7335,41,2973,4617,1391,8291...          2.0
# 4                                                      37          2.0
# 5       92,5,4871,3082,858,2962,28072,5392,4668,38,462...          2.0
#
#         max_players  min_players_rec  max_players_rec  ...  stddev_rating  \
# bgg_id                                                 ...
# 1               5.0              4.0              5.0  ...        1.57510
# 2               4.0              3.0              4.0  ...        1.46752
# 3               4.0              2.0              4.0  ...        1.19279
# 4               4.0              2.0              4.0  ...        1.23667
# 5               6.0              3.0              6.0  ...        1.33603
#
#         bayes_rating  complexity  language_dependency  bga_id  dbpedia_id  \
# bgg_id
# 1            7.06367      4.3144             1.166667     NaN         NaN
# 2            5.76599      1.9636                  NaN     NaN         NaN
# 3            7.22869      2.4784             1.006579     NaN         NaN
# 4            5.66660      2.6667                  NaN     NaN         NaN
# 5            7.12541      2.4985             1.095890     NaN         NaN
#
#        luding_id spielen_id  wikidata_id  wikipedia_id
# bgg_id
# 1            NaN        NaN          NaN           NaN
# 2            NaN        NaN          NaN           NaN
# 3            NaN        NaN          NaN           NaN
# 4            NaN        NaN          NaN           NaN
# 5            NaN        NaN          NaN           NaN
#
# [5 rows x 37 columns]

# %%
df.shape
# Out:
# (113904, 37)

# %%
df.describe()
# Out:
#                 year    min_players    max_players  min_players_rec  \
# count  104219.000000  111966.000000  108448.000000    111966.000000
# mean     2001.765551       2.020703       6.908306         2.025892
# std        66.493704       0.817943      49.819444         0.823590
# min     -3500.000000       1.000000       1.000000         1.000000
# 25%      1998.000000       2.000000       4.000000         2.000000
# 50%      2011.000000       2.000000       4.000000         2.000000
# 75%      2018.000000       2.000000       6.000000         2.000000
# max      2026.000000      50.000000   11299.000000        50.000000
#
#        max_players_rec  min_players_best  max_players_best       min_age  \
# count    108448.000000     111966.000000     108448.000000  90641.000000
# mean          6.887328          2.061403          6.861168      9.517437
# std          49.807438          0.862756         49.809422      7.471185
# min           1.000000          1.000000          1.000000      1.000000
# 25%           4.000000          2.000000          4.000000      8.000000
# 50%           4.000000          2.000000          4.000000     10.000000
# 75%           6.000000          2.000000          6.000000     12.000000
# max       11299.000000         50.000000      11299.000000   2017.000000
#
#        min_age_rec       min_time  ...  stddev_rating  bayes_rating  \
# count  1126.000000   91342.000000  ...   68497.000000  24934.000000
# mean      9.863855      50.787622  ...       1.511145      5.677975
# std       2.824199     604.980910  ...       0.625139      0.357619
# min       2.045455       1.000000  ...       0.000500      3.624890
# 25%       7.987899      15.000000  ...       1.176210      5.509562
# 50%      10.000000      30.000000  ...       1.465140      5.541855
# 75%      11.973319      60.000000  ...       1.776240      5.662987
# max      20.541667  157680.000000  ...       4.500000      8.423300
#
#          complexity  language_dependency  bga_id  dbpedia_id  luding_id  \
# count  48290.000000           854.000000     0.0         0.0        0.0
# mean       1.902059             2.113773     NaN         NaN        NaN
# std        0.830024             1.191279     NaN         NaN        NaN
# min        1.000000             1.000000     NaN         NaN        NaN
# 25%        1.000000             1.013607     NaN         NaN        NaN
# 50%        2.000000             1.778424     NaN         NaN        NaN
# 75%        2.414025             3.063077     NaN         NaN        NaN
# max        5.000000             4.983333     NaN         NaN        NaN
#
#        spielen_id  wikidata_id  wikipedia_id
# count         0.0          0.0           0.0
# mean          NaN          NaN           NaN
# std           NaN          NaN           NaN
# min           NaN          NaN           NaN
# 25%           NaN          NaN           NaN
# 50%           NaN          NaN           NaN
# 75%           NaN          NaN           NaN
# max           NaN          NaN           NaN
#
# [8 rows x 26 columns]

# %%
df.isna().sum()
# Out:
# name                        0
# year                     9685
# game_type               88074
# designer                18251
# artist                  66032
# publisher                  52
# min_players              1938
# max_players              5456
# min_players_rec          1938
# max_players_rec          5456
# min_players_best         1938
# max_players_best         5456
# min_age                 23263
# min_age_rec            112778
# min_time                22562
# max_time                22562
# category                 2214
# mechanic                16767
# cooperative            107550
# compilation            112989
# compilation_of         112989
# family                  34859
# implementation         108039
# integration            109784
# rank                    89425
# num_votes               27722
# avg_rating              27722
# stddev_rating           45407
# bayes_rating            88970
# complexity              65614
# language_dependency    113050
# bga_id                 113904
# dbpedia_id             113904
# luding_id              113904
# spielen_id             113904
# wikidata_id            113904
# wikipedia_id           113904
# dtype: int64

# %%
# Remove all empty columns
df = df.dropna(axis=1, how='all')
df.shape
# Out:
# (113904, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 113904 entries, 1 to 392146
# Data columns (total 31 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   name                 113904 non-null  object
#  1   year                 104219 non-null  float64
#  2   game_type            25830 non-null   object
#  3   designer             95653 non-null   object
#  4   artist               47872 non-null   object
#  5   publisher            113852 non-null  object
#  6   min_players          111966 non-null  float64
#  7   max_players          108448 non-null  float64
#  8   min_players_rec      111966 non-null  float64
#  9   max_players_rec      108448 non-null  float64
#  10  min_players_best     111966 non-null  float64
#  11  max_players_best     108448 non-null  float64
#  12  min_age              90641 non-null   float64
#  13  min_age_rec          1126 non-null    float64
#  14  min_time             91342 non-null   float64
#  15  max_time             91342 non-null   float64
#  16  category             111690 non-null  object
#  17  mechanic             97137 non-null   object
#  18  cooperative          6354 non-null    float64
#  19  compilation          915 non-null     float64
#  20  compilation_of       915 non-null     object
#  21  family               79045 non-null   object
#  22  implementation       5865 non-null    object
#  23  integration          4120 non-null    object
#  24  rank                 24479 non-null   float64
#  25  num_votes            86182 non-null   float64
#  26  avg_rating           86182 non-null   float64
#  27  stddev_rating        68497 non-null   float64
#  28  bayes_rating         24934 non-null   float64
#  29  complexity           48290 non-null   float64
#  30  language_dependency  854 non-null     float64
# dtypes: float64(20), object(11)
# memory usage: 27.8+ MB

# %%
df_filtered = df[~df['year'].isna()]
df_filtered.isna().sum()
# Out:
# name                        0
# year                        0
# game_type               79419
# designer                14803
# artist                  58266
# publisher                  44
# min_players              1501
# max_players              4520
# min_players_rec          1501
# max_players_rec          4520
# min_players_best         1501
# max_players_best         4520
# min_age                 19902
# min_age_rec            103095
# min_time                18601
# max_time                18601
# category                 1903
# mechanic                14744
# cooperative             98164
# compilation            103338
# compilation_of         103338
# family                  31055
# implementation          98543
# integration            100184
# rank                    79950
# num_votes               23113
# avg_rating              23113
# stddev_rating           38748
# bayes_rating            79499
# complexity              57679
# language_dependency    103366
# dtype: int64

# %%
df_filtered['year'] = df_filtered['year'].astype(int)
df_filtered.sample(5)
# Out:
# /var/folders/rj/v6fsj80j7h1g3x5kqtd_p84m0000gn/T/ipykernel_80042/2168319459.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['year'] = df_filtered['year'].astype(int)
#                      name  year game_type designer artist publisher  \
# bgg_id
# 153112          Community  2012       NaN        3  63030      6531
# 75233               Le 55  2004       NaN        3    NaN     17818
# 147757          Financier  1974       NaN        4    NaN   752,130
# 1884    Fireside Football  1996       NaN      792    NaN       103
# 16286         Purdueopoly  1986       NaN        3    NaN       647
#
#         min_players  max_players  min_players_rec  max_players_rec  ...  \
# bgg_id                                                              ...
# 153112          1.0          5.0              1.0              5.0  ...
# 75233           2.0         10.0              2.0             10.0  ...
# 147757          2.0          4.0              2.0              4.0  ...
# 1884            3.0          6.0              3.0              6.0  ...
# 16286           2.0          5.0              2.0              5.0  ...
#
#         family  implementation  integration     rank  num_votes  avg_rating  \
# bgg_id
# 153112     NaN             NaN          NaN      NaN       14.0     5.57143
# 75233    22783             NaN          NaN      NaN        NaN         NaN
# 147757     NaN             NaN          NaN      NaN        4.0     6.12500
# 1884      5551             NaN          NaN  17859.0       63.0     5.88889
# 16286      100             NaN          NaN      NaN       10.0     6.15000
#
#        stddev_rating bayes_rating  complexity  language_dependency
# bgg_id
# 153112       2.02535          NaN      1.0000                  NaN
# 75233            NaN          NaN         NaN                  NaN
# 147757       1.88331          NaN      2.0000                  NaN
# 1884         1.40431      5.51153      1.6667                  NaN
# 16286        1.70367          NaN         NaN                  NaN
#
# [5 rows x 31 columns]

# %%
count_year = df_filtered.groupby('year')['name'].count().to_frame()
plt.figure(figsize=(40, 6))
sns.barplot(data=count_year, x ='year', y = 'name')
plt.xticks(rotation=45, ha ='right', size = 4)
plt.show()

# %%
df_filtered.describe()
# Out:
#                 year    min_players   max_players  min_players_rec  \
# count  104219.000000  102718.000000  99699.000000    102718.000000
# mean     2001.765551       2.016638      6.880250         2.022255
# std        66.493704       0.807291     51.684912         0.813481
# min     -3500.000000       1.000000      1.000000         1.000000
# 25%      1998.000000       2.000000      4.000000         2.000000
# 50%      2011.000000       2.000000      4.000000         2.000000
# 75%      2018.000000       2.000000      6.000000         2.000000
# max      2026.000000      50.000000  11299.000000        50.000000
#
#        max_players_rec  min_players_best  max_players_best       min_age  \
# count     99699.000000     102718.000000      99699.000000  84317.000000
# mean          6.858314          2.060934          6.829918      9.573609
# std          51.673133          0.856575         51.675196      7.675874
# min           1.000000          1.000000          1.000000      1.000000
# 25%           4.000000          2.000000          3.000000      8.000000
# 50%           4.000000          2.000000          4.000000     10.000000
# 75%           6.000000          2.000000          6.000000     12.000000
# max       11299.000000         50.000000      11299.000000   2017.000000
#
#        min_age_rec       min_time      max_time  cooperative  compilation  \
# count  1124.000000   85618.000000  8.561800e+04       6055.0        881.0
# mean      9.870931      50.870004  1.384615e+03          1.0          1.0
# std       2.820472     622.631465  2.448270e+05          0.0          0.0
# min       2.045455       1.000000  1.000000e+00          1.0          1.0
# 25%       7.997768      15.000000  2.000000e+01          1.0          1.0
# 50%      10.000000      30.000000  4.000000e+01          1.0          1.0
# 75%      11.973853      60.000000  6.000000e+01          1.0          1.0
# max      20.541667  157680.000000  6.307200e+07          1.0          1.0
#
#                rank      num_votes    avg_rating  stddev_rating  bayes_rating  \
# count  24269.000000   81106.000000  81106.000000   65471.000000  24720.000000
# mean   12191.000494     280.579661      6.178445       1.514818      5.679409
# std     7059.605138    2215.131768      1.570296       0.615629      0.358510
# min        1.000000       1.000000      1.000000       0.000500      3.624890
# 25%     6076.000000       2.000000      5.280000       1.190235      5.509898
# 50%    12165.000000       8.000000      6.225000       1.468120      5.542390
# 75%    18311.000000      46.000000      7.083330       1.774515      5.665225
# max    24481.000000  119186.000000     10.000000       4.500000      8.423300
#
#          complexity  language_dependency
# count  46540.000000           853.000000
# mean       1.906881             2.111757
# std        0.827212             1.190520
# min        1.000000             1.000000
# 25%        1.000000             1.013514
# 50%        2.000000             1.777778
# 75%        2.428600             3.060000
# max        5.000000             4.983333

# %% [markdown]
# I observed that some of the board games have been released before year 1900 which is quite interesting. To discover whether these are typing/scraping errors or valid entries in a dataset, lets count how many board games have been released before 1950, and let's have a look at some of them.

# %%
before1900 = df_filtered[df_filtered['year'] < 1900]
before1900.shape[0]
# Out:
# 1015

# %%
before1900.sample(10)
# Out:
#                                         name  year game_type  designer artist  \
# bgg_id
# 12856                         Shove Ha'penny  1840       NaN         3    NaN
# 154547                              Pleiades  1879       NaN     73375    NaN
# 11693   The Amusing Game of Innocence Abroad  1888       NaN  991,3988    NaN
# 27791                    The Game of Society  1874       NaN         3    NaN
# 227530         The Good Old Game of Proverbs  1893       NaN         3      3
# 188040                  Fly Away Jack & Jill  1894       NaN         3      3
# 249407           Mother Earth's Produce Game  1897       NaN    108049    NaN
# 308021                        Game of Cities  1889       NaN       NaN    NaN
# 34317                   Shatranj Diwana Shah  1800      4666         3    NaN
# 11652        Round the World with Nellie Bly  1890       NaN         3    NaN
#
#                  publisher  min_players  max_players  min_players_rec  \
# bgg_id
# 12856   171,1017,5722,3277          2.0          2.0              2.0
# 154547            171,2551          2.0          NaN              2.0
# 11693                   28          2.0          4.0              2.0
# 27791                 6502          2.0          6.0              2.0
# 227530                  28          2.0          NaN              2.0
# 188040                2551          2.0          6.0              2.0
# 249407                8999          2.0          NaN              2.0
# 308021                7666          NaN          NaN              NaN
# 34317            171,38726          2.0          2.0              2.0
# 11652           11860,2551          2.0          4.0              2.0
#
#         max_players_rec  ...           family  implementation  integration  \
# bgg_id                   ...
# 12856               2.0  ...            61979             NaN          NaN
# 154547              NaN  ...            24450             NaN          NaN
# 11693               4.0  ...              NaN             NaN          NaN
# 27791               6.0  ...              NaN             NaN          NaN
# 227530              NaN  ...              NaN             NaN          NaN
# 188040              6.0  ...            66189             NaN          NaN
# 249407              NaN  ...              NaN             NaN          NaN
# 308021              NaN  ...              NaN             NaN          NaN
# 34317               2.0  ...  4053,61979,4024             NaN          NaN
# 11652               4.0  ...       9314,73596             NaN          NaN
#
#            rank  num_votes  avg_rating stddev_rating bayes_rating  complexity  \
# bgg_id
# 12856   17936.0       50.0     6.08400       1.76515      5.51098        1.25
# 154547      NaN        NaN         NaN           NaN          NaN         NaN
# 11693       NaN        4.0     4.75000       1.08972          NaN        1.00
# 27791       NaN        1.0     7.00000           NaN          NaN         NaN
# 227530      NaN        NaN         NaN           NaN          NaN         NaN
# 188040      NaN        1.0     6.00000           NaN          NaN         NaN
# 249407      NaN        NaN         NaN           NaN          NaN         NaN
# 308021      NaN        NaN         NaN           NaN          NaN         NaN
# 34317       NaN        7.0     3.21429       1.46036          NaN         NaN
# 11652       NaN        7.0     4.45714       1.26362          NaN         NaN
#
#         language_dependency
# bgg_id
# 12856                   NaN
# 154547                  NaN
# 11693                   NaN
# 27791                   NaN
# 227530                  NaN
# 188040                  NaN
# 249407                  NaN
# 308021                  NaN
# 34317                   NaN
# 11652                   NaN
#
# [10 rows x 31 columns]

# %%
before1900[before1900.year<500].shape[0]
# Out:
# 27

# %%
#the oldest board games
before1900[before1900.year<500]
# Out:
#                                             name  year  game_type designer  \
# bgg_id
# 188                                           Go -2200       4666        3
# 1602                        The Royal Game of Ur -2600       4666        3
# 2136                                     Pachisi   400  4665,5499        3
# 2399                                       Senet -3500       4666        3
# 2912    Hounds and Jackals: Game of the Pharaohs -2000        NaN        3
# 2932                                   Hnefatafl   400       4666        3
# 3886                           Nine Men's Morris -1400       4666        3
# 4148                                       Mehen -3000       4666        3
# 5432                          Chutes and Ladders  -200       4665        3
# 5546                                     Marbles -3000       4665        3
# 11726                               Knucklebones -3000        NaN        3
# 11901                                Tic-Tac-Toe -1300  4665,4666        3
# 13776                                  Ashtapada  -350       4666        3
# 19915                         Three Men's Morris -1400       4666        3
# 21488                                    Petteia  -100       4666    11064
# 22610                                      Liubo  -700       4666        3
# 23211                                 20 Squares -3000        NaN        3
# 25702                           Six Men's Morris -1400       4666        3
# 28128                                    Pah Tum -1800       4666        3
# 28931                                       Achi   300       4666        3
# 37701                                Five Stones -2000        NaN        3
# 39628                                     Jiroft -2600        NaN        3
# 40412                                    Fan Tan  -600        NaN        3
# 96554                                     Tabula    41        NaN      NaN
# 102420                                 T'shu-p'u   220        NaN      NaN
# 180952                        Seven Men's Morris -1400        NaN        3
# 340997                                Five Lines  -600        NaN      NaN
#
#                                                    artist  \
# bgg_id
# 188                                           33954,70252
# 1602                                        109537,132798
# 2136    59100,9620,52372,54043,30281,6710,53833,141083...
# 2399                              64922,128192,7628,79195
# 2912                                                 7628
# 2932                            132798,147223,10384,60765
# 3886                                  109537,130246,60765
# 4148                                                 7628
# 5432    52810,71033,8810,63030,10171,6710,141083,9988,...
# 5546                                                  NaN
# 11726                                                 NaN
# 11901                                                 NaN
# 13776                                                 NaN
# 19915                                                 NaN
# 21488                                                9393
# 22610                                                 NaN
# 23211                                                 NaN
# 25702                                                 NaN
# 28128                                              130246
# 28931                                                 NaN
# 37701                                                 NaN
# 39628                                                 NaN
# 40412                                                 NaN
# 96554                                                 NaN
# 102420                                                NaN
# 180952                                                  3
# 340997                                                NaN
#
#                                                 publisher  min_players  \
# bgg_id
# 188     171,92,404,362,5,4922,4680,35302,6765,3828,130...          2.0
# 1602    171,22447,3251,3025,3115,24921,5085,6262,50685...          2.0
# 2136    171,9607,10814,7533,404,18931,16840,662,74,524...          2.0
# 2399    171,4,1017,553,7639,586,200,5085,384,24576,506...          2.0
# 2912                   171,3115,50685,15351,7938,5915,642          2.0
# 2932    171,1017,404,1997,74,35302,4109,27434,3115,511...          2.0
# 3886    171,4,1017,6514,1448,22447,73,10992,31495,1935...          2.0
# 4148        171,8756,3115,5085,50685,6266,5915,2432,45967          2.0
# 5432    171,20,1001,2008,1017,10814,30,690,4680,7548,2...          2.0
# 5546        171,225,5314,1195,50975,635,93,782,29995,1722          1.0
# 11726                        171,3320,5314,5722,6720,7063          2.0
# 11901   171,3320,1017,6514,33079,225,5314,2401,18726,1...          2.0
# 13776                                            171,3115          2.0
# 19915                                            171,6261          2.0
# 21488   171,3115,5085,53512,50685,6266,10094,49182,182...          2.0
# 22610                                                 171          2.0
# 23211                                           171,50685          2.0
# 25702                                              171,20          2.0
# 28128                                           171,50098          2.0
# 28931                           171,38726,6432,6266,49182          2.0
# 37701                                            171,5314          1.0
# 39628                                                 171          NaN
# 40412                                                 171          3.0
# 96554                                     171,50685,24407          2.0
# 102420                                              171,4          4.0
# 180952                                                171          2.0
# 340997                                              49182          2.0
#
#         max_players  min_players_rec  max_players_rec  ...  \
# bgg_id                                                 ...
# 188             2.0              2.0              2.0  ...
# 1602            2.0              2.0              2.0  ...
# 2136            6.0              2.0              4.0  ...
# 2399            2.0              2.0              2.0  ...
# 2912            2.0              2.0              2.0  ...
# 2932            2.0              2.0              2.0  ...
# 3886            2.0              2.0              2.0  ...
# 4148            6.0              2.0              6.0  ...
# 5432            6.0              2.0              6.0  ...
# 5546           99.0              1.0             99.0  ...
# 11726           2.0              2.0              2.0  ...
# 11901           2.0              2.0              2.0  ...
# 13776           2.0              2.0              2.0  ...
# 19915           2.0              2.0              2.0  ...
# 21488           2.0              2.0              2.0  ...
# 22610           2.0              2.0              2.0  ...
# 23211           2.0              2.0              2.0  ...
# 25702           2.0              2.0              2.0  ...
# 28128           2.0              2.0              2.0  ...
# 28931           2.0              2.0              2.0  ...
# 37701           4.0              1.0              4.0  ...
# 39628           NaN              NaN              NaN  ...
# 40412           8.0              3.0              8.0  ...
# 96554           2.0              2.0              2.0  ...
# 102420          4.0              4.0              4.0  ...
# 180952          2.0              2.0              2.0  ...
# 340997          2.0              2.0              2.0  ...
#
#                                                    family  implementation  \
# bgg_id
# 188     26432,78562,78571,78641,78574,73591,68769,7036...             NaN
# 1602                         57934,70948,61979,18186,4023           39628
# 2136    4214,7334,7349,18409,5597,28738,10407,63150,10...             NaN
# 2399        72535,27383,6471,70360,70711,61938,61979,4023             NaN
# 2912                                     72535,7349,61979             NaN
# 2932    26432,78565,78571,25158,68769,73590,80224,7843...             NaN
# 3886    26432,78573,68769,70360,80224,80226,70354,6197...             NaN
# 4148                                                72535             NaN
# 5432    46165,7265,7334,7269,7509,10129,20335,11209,18...             NaN
# 5546                                 5902,73590,6363,5552             NaN
# 11726                                         61979,46063             NaN
# 11901        4220,6994,26432,78572,61979,21540,5619,19291             NaN
# 13776                                         62518,61979             NaN
# 19915                              26432,78572,61979,4219             NaN
# 21488                   78581,62518,8374,70711,61979,4055             NaN
# 22610                                               61979             NaN
# 23211                                               61979             NaN
# 25702                                    26432,61979,4219             NaN
# 28128                              4220,78573,80225,61979             NaN
# 28931                         4220,78572,59502,8374,61979             NaN
# 37701                                               46063             NaN
# 39628                                        57934,4023,9             NaN
# 40412                                                 NaN             NaN
# 96554                                     5606,61979,4023             NaN
# 102420                                               4214             NaN
# 180952                                         61979,4219             NaN
# 340997                                                NaN             NaN
#
#         integration     rank  num_votes  avg_rating stddev_rating  \
# bgg_id
# 188             NaN    194.0    16604.0     7.64323       1.90884
# 1602            NaN   7056.0      716.0     6.11016       1.77279
# 2136            NaN  24224.0     5237.0     4.50697       1.88432
# 2399         173264   9628.0      788.0     5.82329       1.66428
# 2912            NaN      NaN       21.0     4.86667       2.18944
# 2932            NaN   2940.0     1514.0     6.62856       1.46582
# 3886            NaN  24142.0     1563.0     5.34553       1.61864
# 4148            NaN      NaN       17.0     5.55882       1.98437
# 5432            NaN  24222.0     4412.0     2.89101       1.66474
# 5546            NaN  24362.0      515.0     4.72173       1.70749
# 11726           NaN  19185.0       36.0     5.77778       1.34084
# 11901           NaN  24230.0     3724.0     2.73514       1.99005
# 13776           NaN      NaN        2.0     7.50000       2.50000
# 19915           NaN  23619.0       68.0     4.43103       1.90941
# 21488           NaN  17249.0       66.0     6.03561       1.59649
# 22610           NaN      NaN        2.0     8.00000       1.00000
# 23211           NaN      NaN        1.0     3.00000           NaN
# 25702           NaN      NaN       23.0     4.64348       1.45985
# 28128           NaN      NaN        9.0     5.55556       1.70692
# 28931           NaN      NaN       25.0     4.14800       1.95492
# 37701           NaN      NaN       14.0     5.76429       1.68422
# 39628           NaN      NaN        1.0     7.00000           NaN
# 40412           NaN      NaN        1.0     4.00000           NaN
# 96554           NaN      NaN       11.0     6.59091       1.51984
# 102420          NaN      NaN        4.0     6.25000       3.03109
# 180952          NaN      NaN        1.0     7.00000           NaN
# 340997          NaN      NaN        1.0     1.00000           NaN
#
#        bayes_rating  complexity  language_dependency
# bgg_id
# 188         7.31279      3.9338             1.010753
# 1602        5.62353      1.2857                  NaN
# 2136        4.69962      1.1931             1.020833
# 2399        5.56898         NaN                  NaN
# 2912            NaN      1.0000                  NaN
# 2932        5.96272      2.5000                  NaN
# 3886        5.40718      1.8231                  NaN
# 4148            NaN      1.0000                  NaN
# 5432        3.64057      1.0305             1.000000
# 5546        5.33775      1.1000                  NaN
# 11726       5.50534      1.0000                  NaN
# 11901       3.62489      1.2874             1.016667
# 13776           NaN         NaN                  NaN
# 19915       5.45918      1.2222                  NaN
# 21488       5.51434      2.1667                  NaN
# 22610           NaN         NaN                  NaN
# 23211           NaN         NaN                  NaN
# 25702           NaN      2.0000                  NaN
# 28128           NaN      1.5000                  NaN
# 28931           NaN      1.2500                  NaN
# 37701           NaN      1.0000                  NaN
# 39628           NaN         NaN                  NaN
# 40412           NaN         NaN                  NaN
# 96554           NaN      1.5000                  NaN
# 102420          NaN         NaN                  NaN
# 180952          NaN         NaN                  NaN
# 340997          NaN         NaN                  NaN
#
# [27 rows x 31 columns]

# %% [markdown]
# Indeed, looks like the game release years were correctly scraped from the website ( I manually verified on boardgamegeek the following games Parchisi, Crokinole, Conflict, Aadu Puli Attam). These are very old board games.

# %%
after1900 = df_filtered[df_filtered['year'] >= 1900]
after1900.describe()
# Out:
#                 year    min_players   max_players  min_players_rec  \
# count  103204.000000  101865.000000  98999.000000    101865.000000
# mean     2004.590636       2.015619      6.877595         2.021195
# std        18.970729       0.807908     51.849572         0.814040
# min      1900.000000       1.000000      1.000000         1.000000
# 25%      1998.000000       2.000000      4.000000         2.000000
# 50%      2011.000000       2.000000      4.000000         2.000000
# 75%      2018.000000       2.000000      6.000000         2.000000
# max      2026.000000      50.000000  11299.000000        50.000000
#
#        max_players_rec  min_players_best  max_players_best       min_age  \
# count     98999.000000     101865.000000      98999.000000  84008.000000
# mean          6.856706          2.059972          6.828281      9.579028
# std          51.838568          0.857199         51.840632      7.687685
# min           1.000000          1.000000          1.000000      1.000000
# 25%           4.000000          2.000000          3.000000      8.000000
# 50%           4.000000          2.000000          4.000000     10.000000
# 75%           6.000000          2.000000          6.000000     12.000000
# max       11299.000000         50.000000      11299.000000   2017.000000
#
#        min_age_rec       min_time      max_time  cooperative  compilation  \
# count  1103.000000   85184.000000  8.518400e+04       6055.0        881.0
# mean      9.932607      50.886927  1.391415e+03          1.0          1.0
# std       2.791716     624.113179  2.454499e+05          0.0          0.0
# min       2.045455       1.000000  1.000000e+00          1.0          1.0
# 25%       8.024002      15.000000  2.000000e+01          1.0          1.0
# 50%      10.027778      30.000000  4.000000e+01          1.0          1.0
# 75%      11.993902      60.000000  6.000000e+01          1.0          1.0
# max      20.541667  157680.000000  6.307200e+07          1.0          1.0
#
#                rank      num_votes    avg_rating  stddev_rating  bayes_rating  \
# count  24147.000000   80638.000000  80638.000000   65140.000000  24598.000000
# mean   12180.779434     279.438850      6.181604       1.513923      5.679941
# std     7050.184491    2214.190308      1.568539       0.614862      0.357383
# min        1.000000       1.000000      1.000000       0.000500      3.824630
# 25%     6074.000000       2.000000      5.285710       1.189475      5.509970
# 50%    12160.000000       8.000000      6.227290       1.467140      5.542465
# 75%    18294.000000      46.000000      7.084370       1.773315      5.665415
# max    24481.000000  119186.000000     10.000000       4.500000      8.423300
#
#          complexity  language_dependency
# count  46288.000000           835.000000
# mean       1.906851             2.134765
# std        0.826724             1.192712
# min        1.000000             1.000000
# 25%        1.000000             1.015625
# 50%        2.000000             1.878788
# 75%        2.428600             3.072193
# max        5.000000             4.983333

# %%
after1900[after1900['year']>2024].shape[1]
# Out:
# 31

# %%
count_year = before1900.groupby('year')['name'].count().to_frame()
plt.figure(figsize=(25, 6))
sns.barplot(data=count_year, x ='year', y = 'name')
plt.xticks(rotation=45, ha ='right', size = 5)
plt.show()

# %%
count_year = after1900.groupby('year')['name'].count().to_frame()
sns.set_palette('husl')
plt.figure(figsize=(15, 6))
sns.barplot(data=count_year, x = 'year', y = 'name')
plt.xticks(rotation=45, ha ='right', size = 5)
plt.ylabel('Number of board games')
plt.title('Board game release by year')
plt.show()

# %% [markdown]
# As shown on the barplot above, there is a noticeble increase in board games releases starting from around 2000. For further analysis I decided to retain only games released after 2000 and with rating which is based on at least 5 votes.

# %%
#to filter only rows where avg rating is present and number of votes is > 20, after year 2000
df2000 = df_filtered[(~df_filtered['avg_rating'].isna()) & (df_filtered['num_votes']>20) & (df_filtered['year']>=2000)]
df2000.shape
# Out:
# (22903, 31)

# %%
count_year = df2000.groupby('year')['name'].count().to_frame()
sns.set_palette('husl')
plt.figure(figsize=(15, 6))
sns.barplot(data=count_year, x = 'year', y = 'name')
plt.xticks(rotation=45, ha ='right', size = 5)
plt.ylabel('Number of board games')
plt.title('Board game release by year')
plt.show()

# %% [markdown]
# It is noticeable that the number of released games in years 2020-24 has decreased; however, this might only reflect the fact that not all released games have received enough ratings to be included in the dataset.

# %%
plt.figure(figsize=(35, 6))
sns.boxplot(data=df2000, y = 'avg_rating', x='year', hue = 'year', palette = 'husl', legend = False, showfliers = False)
sns.stripplot(data=df2000, y = 'avg_rating', x='year', size = 2, color = 'grey')
plt.ylabel('Average rating')
plt.title('Board game ratings by year')

medians = df2000.groupby(['year'])['avg_rating'].median().values
for xtick in plt.gca().get_xticks():
    plt.text(xtick, medians[xtick], f'{medians[xtick]:.1f}', 
             horizontalalignment='center', size='medium', color='black')
plt.show()

# %%
plt.figure(figsize=(35, 6))
sns.boxplot(data=df2000, y = 'complexity', x='year', hue = 'year', palette = 'husl', legend = False, showfliers = False)
sns.stripplot(data=df2000, y = 'complexity', x='year', size = 2, color = 'grey')
plt.ylabel('Complexity')
plt.title('Board game complexity by year')

medians = df2000.groupby(['year'])['complexity'].median().values
for xtick in plt.gca().get_xticks():
    plt.text(xtick, medians[xtick], f'{medians[xtick]:.1f}', 
             horizontalalignment='center', size='medium', color='black')
plt.show()

# %% [markdown]
# The average rating of board games has increased in the last two decades, from 5.7 in 2000 to 7.3 in 2022.

# %%
#to find the most popular board games, I decided to select only games with number of voters more than 10000 and sort these games based on the average rating
df2000top = df2000[df2000['num_votes']>10000]
top20 = df2000top.sort_values(by='avg_rating', ascending=False).iloc[:20]
barplot = sns.barplot(data=top20, y = 'name', x = 'avg_rating', hue = 'complexity')
plt.title('The most popular board games released after 2000')
# Adding year of release as labels
for index, value in enumerate(top20['avg_rating']):
    barplot.text(value, index, f" {top20.iloc[index]['complexity']}", color='black', va="center")

plt.show()

# %% [markdown]
# Next, let's find out the best board games for pre-schoolers!

# %%
#in this case I will apply less strict filter on number of voters, as children games are not so popular.
preschool = df2000[(df2000['num_votes']>100) & (df2000['min_age']<5)] 
top20Preschool = preschool.sort_values(by='avg_rating', ascending=False).iloc[:20]
barplot = sns.barplot(data=top20Preschool, y = 'name', x = 'avg_rating')
plt.title('The most popular board games for pre-schoolers')
plt.ylabel(None)
# Adding year of release as labels
for index, value in enumerate(top20Preschool['avg_rating']):
    barplot.text(value, index, f" {top20Preschool.iloc[index]['complexity']}", color='black', va="center")

plt.show()

# %%
#in this case I will apply less strict filter on number of voters, as children games are not so popular.
preschool = df2000[(df2000['num_votes']>100) & (df2000['min_age']<=5)] 
top20Preschool = preschool.sort_values(by='rank', ascending=True).iloc[:20]
barplot = sns.barplot(data=top20Preschool, y = 'name', x = 'rank')
plt.title('The most popular board games for pre-schoolers')
plt.ylabel(None)
# Adding year of release as labels
for index, value in enumerate(top20Preschool['rank']):
    barplot.text(value, index, f" {top20Preschool.iloc[index]['complexity']}", color='black', va="center")

plt.show()

# %%
sns.histplot(data=df2000, x = 'max_time')
plt.show()
